# %%
import pandas as pd

try:
    df = pd.read_csv('personality_datasert.csv')
    print("Data berhasil dimuat!")
    print("\nLima baris pertama data:")
    print(df.head())
    print("\nInformasi umum tentang data:")
    print(df.info())
    print("\nStatistik deskripsif data:")
    print(df.describe())
except FileNotFoundError:
    print("Error: File 'personality_datasert.cvs' tidak ditemukan. pastikan file berada di direktori yang benar.")
# Out:
# Data berhasil dimuat!
#
# Lima baris pertama data:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         No                      4.0            6.0
# 1               9.0        Yes                      0.0            0.0
# 2               9.0        Yes                      1.0            2.0
# 3               0.0         No                      6.0            7.0
# 4               3.0         No                      9.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 13.0             5.0   Extrovert
# 1                       Yes                  0.0             3.0   Introvert
# 2                       Yes                  5.0             2.0   Introvert
# 3                        No                 14.0             8.0   Extrovert
# 4                        No                  8.0             5.0   Extrovert
#
# ...

# %% [markdown]
# 🔍 Deskripsi Dataset
# Nama file: personality_datasert.csv
# Ukuran: 112.22 kB
# Jumlah kolom: 8 (di tampilan yang terlihat)
# Jumlah baris: ~2900 (berdasarkan jumlah pada Stage_fear: 1410 true, 1490 false)
#
# 📊 Beberapa Kolom yang Terlihat
# Berikut adalah beberapa fitur (kolom) penting dalam dataset:
#
# Time_spent_Alone
#
# Tipe data numerik.
#
# Menunjukkan jumlah waktu yang dihabiskan sendirian.
#
# Bisa mengindikasikan kecenderungan introvert jika tinggi.
#
# Stage_fear
#
# Nilai boolean: true atau false.
#
# Indikator ketakutan berbicara di depan umum.
#
# Lebih banyak yang false (51%) → mayoritas tidak takut tampil.
#
# Social_event_attendance
#
# Numerik.
#
# Menunjukkan seberapa sering individu menghadiri acara sosial.
#
# Bisa mengindikasikan kecenderungan ekstrovert jika tinggi.
#
# Going_outside
#
# Numerik.
#
# Frekuensi individu keluar rumah.
#
# Bisa mencerminkan keterbukaan sosial.
#
# Drink_alcohol
#
# (terpotong di gambar) tampaknya bernilai Yes/No.
#
# Bisa menjadi fitur sosialisasi atau pengaruh lingkungan.
#
# 📈 Visualisasi Singkat
# Beberapa kolom ditampilkan sebagai histogram:
#
# Distribusi pada Time_spent_Alone dan Social_event_attendance menunjukkan variasi data yang bisa membedakan pola perilaku introvert vs. ekstrovert.
#
# Pie chart untuk Stage_fear menunjukkan pembagian hampir merata.
#
# 🧠 Kemungkinan Analisis Lanjutan
# Dataset ini bisa digunakan untuk:
#
# Klasifikasi: Memprediksi apakah seseorang lebih cenderung introvert atau ekstrovert berdasarkan fitur perilaku.
#
# Clustering: Mengelompokkan individu berdasarkan kesamaan perilaku.
#
# Analisis Korelasi: Melihat hubungan antara perilaku seperti menghadiri acara sosial vs. waktu menyendiri.
#
# Pembuatan Profil: Mengidentifikasi ciri umum dari seorang ekstrovert dan introvert.
#
# 📁 Catatan Tambahan (dari screenshot):
# Terdapat 2 file: kemungkinan versi berbeda dari dataset.
#
# Data ini mungkin berasal dari survei atau kuesioner berbasis self-report.
